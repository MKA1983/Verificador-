# %% [markdown]
# <a href="https://colab.research.google.com/github/MKA1983/Verificador-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar dependências automaticamente no Google Colab
# !pip install flask pyngrok unidecode

from flask import Flask, render_template_string, request
from pyngrok import ngrok
import json
import unidecode

app = Flask(__name__)

# Configurar o ngrok
ngrok.set_auth_token("2uH7eemLYHJ2tvmEaRmwlQwpWRd_22D25ksgE52gyYBmRBPT9")
public_url = ngrok.connect(5000).public_url
print(f" * Acesse a aplicação em: {public_url}")

# Carregar o JSON de convênios
convenios_data = [
    {"nome": "MAX 400"},
    {"nome": "MAX 400 PLUS (401)"},
    {"nome": "MAX 400 PRATA (404)"},
    {"nome": "MAX 500"},
    {"nome": "MAX 500 PLUS (501)"},
    {"nome": "SMART 500"},
    {"nome": "511 SMART 300 PLUS"},
    {"nome": "513 SMART PRIME"},
    {"nome": "EXECUTIVO"},
    {"nome": "704"},
    {"nome": "NDS 130 (3006)"},
    {"nome": "NDS 140 (3007)"},
    {"nome": "NDS 145 (3013)"},
    {"nome": "NDS 150 (3008)"},
    {"nome": "NDS 160 (3009)"},
    {"nome": "NDS 170 (3010)"},
    {"nome": "NDS 180 (3011)"},
    {"nome": "NDS 190 (3012)"},
    {"nome": "TRT NDI 300/310 - BÁSICO"},
    {"nome": "TRT NDS 160 INTERMED"},
    {"nome": "STANDARD TRT"},
    {"nome": "MASTER I/II"},
    {"nome": "NDS STANDARD"},
    {"nome": "NDS SPECIAL"},
    {"nome": "NDS CLASS"},
    {"nome": "NDS EXECUTIVE"},
    {"nome": "NDS SELECT"},
    {"nome": "NDS EXCLUSIVE"},
    {"nome": "NDS GTA 011"},
    {"nome": "NDS GTA 030-GZ"},
    {"nome": "NDS GT/GTA (3043)"},
    {"nome": "NDS REDE 1 (3051)"},
    {"nome": "NDS REDE 2 (3052)"},
    {"nome": "NDS REDE 3 (3053)"},
    {"nome": "NDS REDE 4 (3054)"},
    {"nome": "NDS 10 (3061)"},
    {"nome": "NDS SPECIAL I (3072)"},
    {"nome": "NDS 130 CEAGESP (3076)"},
    {"nome": "NDS 160 CEAGESP (3077)"},
    {"nome": "NDS 170 CEAGESP (3078)"},
    {"nome": "NDS 180 CEAGESP (3079)"},
    {"nome": "NDS 190 CEAGESP (3080)"},
    {"nome": "ADVANCE 600 (725)"},
    {"nome": "ADVANCE 600 A (735)"},
    {"nome": "ADVANCE 700 (726)"},
    {"nome": "ADVANCE 700 A (736)"},
    {"nome": "PREMIUM 800 (756)"},
    {"nome": "PREMIUM 900 (757)"},
    {"nome": "INFINITY 1000 (758)"},
    {"nome": "INFINITY 1000 PLUS (759)"},
    {"nome": "PREMIUM 800 LASA (760)"},
    {"nome": "ADVANCE 600 CARE (747)"},
    {"nome": "ADVANCE 600 A CARE (748)"},
    {"nome": "ADVANCE 700 CARE (777)"},
    {"nome": "ADVANCE 700 A CARE (778)"},
    {"nome": "PREMIUM 800 CARE (822)"},
    {"nome": "PREMIUM 900 CARE"},
    {"nome": "INFINITY 1000 CARE"},
    {"nome": "PREMIUM TRT I (938)"},
    {"nome": "PREMIUM TRT II (939)"}
]

# Função para verificar se o convênio é aceito
def verificar_convenio(nome_plano):
    nome_plano = unidecode.unidecode(nome_plano).upper().strip()

    for convenio in convenios_data:
        if isinstance(convenio, dict) and "nome" in convenio:  # Verifica se o item é um dicionário e tem "nome"
            if unidecode.unidecode(convenio["nome"]).upper().strip() == nome_plano:
                return f'<span style="color: green; font-weight: bold;">{nome_plano} É ACEITO.</span>'

    return f'<span style="color: red; font-weight: bold;">{nome_plano} NÃO É ACEITO.</span>'

# Interface HTML melhorada
HTML_TEMPLATE = """
<!DOCTYPE html>
<html lang="pt-br">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Verificador de Convênios Intermédica</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background-color: #f4f4f4;
            text-align: center;
            padding: 20px;
        }
        .container {
            max-width: 400px;
            background: white;
            padding: 20px;
            margin: 0 auto;
            border-radius: 10px;
            box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);
        }
        h1 {
            color: #333;
        }
        input, button {
            width: 100%;
            padding: 10px;
            margin: 10px 0;
            border-radius: 5px;
            border: 1px solid #ccc;
        }
        button {
            background-color: #007BFF;
            color: white;
            border: none;
            cursor: pointer;
        }
        button:hover {
            background-color: #0056b3;
        }
        .resultado {
            font-size: 18px;
            margin-top: 15px;
            padding: 10px;
            border-radius: 5px;
        }
    </style>
</head>
<body>
    <div class="container">
        <h1>Verificador de Convênios Intermédica</h1>
        <form method="post">
            <input type="text" name="plano" placeholder="Digite o nome do convênio" required>
            <button type="submit">Verificar</button>
        </form>
        <div class="resultado">{{ resultado|safe }}</div>
    </div>
</body>
</html>
"""

@app.route("/", methods=["GET", "POST"])
def home():
    resultado = ""
    if request.method == "POST":
        plano = request.form["plano"]
        resultado = verificar_convenio(plano)

    return render_template_string(HTML_TEMPLATE, resultado=resultado)

if __name__ == "__main__":
    app.run()
# Out:
# ...
#  * Acesse a aplicação em: https://865f-34-145-37-40.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# ERROR:root:Unexpected exception finding object shape
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/google/colab/_debugpy_repr.py", line 54, in get_shape
#     shape = getattr(obj, 'shape', None)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/werkzeug/local.py", line 318, in __get__
#     obj = instance._get_current_object()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/werkzeug/local.py", line 519, in _get_current_object
#     raise RuntimeError(unbound_message) from None
# RuntimeError: Working outside of request context.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Nova seção
